# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import codecs
# %matplotlib inline

# %%
with codecs.open("carp_games.csv", "r", "Shift-JIS", "ignore") as file:
    games = pd.read_table(file, delimiter=",")

# %%
games["win"] = 1 if games["carp_score"]
# Out:
#            date  carp_score opponent_name  opponent_score
# 0    2016-04-01           4            巨人               6
# 1    2016-04-02           3            巨人               0
# 2    2016-04-03           3            巨人               4
# 3    2016-04-05          12          ヤクルト               5
# 4    2016-04-06           6          ヤクルト               3
# 5    2016-04-08           2            阪神               3
# 6    2016-04-09           6            阪神               2
# 7    2016-04-10           8            阪神               7
# 8    2016-04-12           3            中日               1
# 9    2016-04-14          10            中日               1
# 10   2016-04-16           5            巨人               6
# 11   2016-04-17           1            巨人               2
# 12   2016-04-19           6          DeNA               4
# 13   2016-04-20           0          DeNA              10
# 14   2016-04-22           9            阪神              12
# ...
